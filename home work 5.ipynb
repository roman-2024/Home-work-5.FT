# %%
import pandas as pd

# %%
df=pd.read_csv("hw5.csv")
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %%
df=df[["price"]]
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df["new price"]= scaler.fit_transform(df[["price"]])
df
# Out:
#    price  new price
# 0    110        0.2
# 1    105        0.1
# 2    115        0.3
# 3    120        0.4
# 4    110        0.2
# 5    130        0.6
# 6    150        1.0
# 7    100        0.0
# 8    105        0.1

# %%
df=df[["price"]]
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %%
df.mean()
# Out:
# price    116.111111
# dtype: float64

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

# %%
df["new price"]= std.fit_transform(df[["price"]])
df
# Out:
#    price  new price
# 0    110  -0.416356
# 1    105  -0.757011
# 2    115  -0.075701
# 3    120   0.264954
# 4    110  -0.416356
# 5    130   0.946264
# 6    150   2.308884
# 7    100  -1.097666
# 8    105  -0.757011

# %%
df=df[["price"]]

# %%
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %% [markdown]
# # MaxAbsScaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
scaler = MaxAbsScaler()
df["MAS price"]= scaler.fit_transform(df[["price"]])
df
# Out:
#    price  MAS price
# 0    110   0.733333
# 1    105   0.700000
# 2    115   0.766667
# 3    120   0.800000
# 4    110   0.733333
# 5    130   0.866667
# 6    150   1.000000
# 7    100   0.666667
# 8    105   0.700000

# %%
df=df[["price"]]
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %% [markdown]
# # RobustScaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()
df["robust price"]= RobustScaler().fit_transform(df[["price"]])
df
# Out:
#    price  robust price
# 0    110      0.000000
# 1    105     -0.333333
# 2    115      0.333333
# 3    120      0.666667
# 4    110      0.000000
# 5    130      1.333333
# 6    150      2.666667
# 7    100     -0.666667
# 8    105     -0.333333
